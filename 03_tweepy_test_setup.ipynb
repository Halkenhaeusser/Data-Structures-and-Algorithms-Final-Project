# %%
#!pip install tweepy
#!pip install pandas

# %% [markdown]
# # Loading required libraries
#
# 1. The ``tweepy`` library (https://docs.tweepy.org/en/stable/) can be used to access the Twitter API for storing the relevant tweets and further information. For using Tweepy to extract tweets, we first needed to apply for developer credentials including private consumer keys and access tokens.
# 2. ``Pandas`` is imported for first minor data transformations and reading in the politician's twitter handles.

# %%
import tweepy
import pandas as pd
import datetime

# %% [markdown]
# As a next step, the personal consumer keys/access tokens must be provided in order to access the Twitter API. In order to receive the keys and tokens, one must apply for twitter developer credentials.

# %%
# Define your access credentials

consumer_key = input("Please input your consumer key")
consumer_secret = input("Please input your consumer secret")

access_token = input("Please input your access key")
access_token_secret = input("Please input your access token secret")

# %% [markdown]
# ### Authentification and connection to the Twitter API
#
# In the next chunk, the previously stored consumer keys are passed to the OAuthHandler instance, using the tweepy library. Subsequently, also the access token and secret need to be set up (which we also have stored in strings in the previous chunk). Finally, a new API variable is created. The `wait_on_rate_limit`-argument is set to true (this is useful since there are certain rate limits set by Twitter which should not be exceeded).

# %%
auth = tweepy.OAuthHandler(
    consumer_key,
    consumer_secret
)

auth.set_access_token(
    access_token,
    access_token_secret
)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ### Testing authentification status
#
# Here, we are testing whether the authentification was successful using the ``verify_credentials``-function of ``tweepy``. In case of exisiting credentials, we are printing a confirmation statement. If an error occurs, we are printing an error statement.

# %%
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %% [markdown]
# ### Testing whether we are able to extract and store tweets
#
# Here, we are extracting the last tweet of Johannes and storing it in an object. For this purpose, we use Tweepy's ``user_timeline``-function, and specify
# - the user name (``screen_name``)
# - the number of tweets we want to display (``count``)
# - whether we want to include retweets (``include_rts``)
# - that we want to display the tweets in extended view (``tweet_mode``)

# %%
tweets = api.user_timeline(
    screen_name = "halkenhaeusser",
    count = 1,
    include_rts = False,
    tweet_mode = 'extended'
)

print(tweets)

# %%
type(tweets)
# Out:
# tweepy.models.ResultSet

# %%
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

# %% [markdown]
# ### Saving twitter handles of German MPs and printing a random handle
#
# Since we want to be theoretically able to analyze the tweets of each German MP using twitter, we need a resource that stores the respective twitter handles of all MPs. For this purpose, we can draw on the work of Markus Konrad from the WZB. In the next chunk, we read in the csv.file containing the twitter handles using ``pandas``. In the following, we store only the twitter handles and dropping all MPs that do not have a twitter account. Furthermore, we use the sample command to display a random handle to check whether the previous code was successful.

# %%
# Sample tweets
wzb_df = pd.read_csv("https://raw.githubusercontent.com/WZBSocialScienceCenter/mdb-twitter-network/master/data/deputies_twitter_20190702.csv")

twitter_df = wzb_df[["twitter_name"]].dropna()

# print(twitter_series)

twitter_sample = twitter_df.sample(n = 1)
# twitter_sample = twitter_sample.loc[:, "twitter_name"]

# print(twitter_sample)
# twitter_sample = twitter_sample.rename_axis(index = None)

twitter_string = twitter_sample.to_string(index = False, header = False)

print(twitter_string)
# type(twitter_string)
# Out:
#  gruenclaudia

# %% [markdown]
# ### Printing the whole dataframe containing every MP
#
# In the following chunk, we print the full data frame created by Markus Konrad. As we can see, it contains several columns with further information.

# %%
wzb_df
# Out:
#      meta.status       meta.edited                             meta.uuid  \
# 0              1  2019-06-07 13:28  3a08158b-eb25-4cff-9594-363493dfb4d0
# 1              1  2019-06-07 13:28  d623efb5-7afc-4b56-a794-dfe6c1def0f9
# 2              1  2019-06-07 13:28  e0209560-579a-4f65-bed9-a189a7146690
# 3              1  2019-06-07 13:28  a96583f1-e2b0-4e41-aa4c-e0494cdff322
# 4              1  2019-06-07 13:28  a5a53285-3632-4854-af0e-1bf301417955
# ..           ...               ...                                   ...
# 713            1  2019-06-07 13:28  0987e856-e99a-4cd5-93bd-0a97e37347aa
# 714            1  2019-06-07 13:28  b8da0922-d041-4a36-a6e2-e98a61f2be86
# 715            1  2019-06-07 13:28  d14354bf-24ee-49e2-ab32-6ca5ebb8248d
# 716            1  2019-06-07 13:28  680d201b-fbfc-4436-939e-9df5fa84d233
# 717            1  2019-06-07 13:28  565b56bc-d7d7-46e5-bcc9-a9c939f3e896
#
#                  meta.username  meta.questions  meta.answers  \
# 0    alexander-graf-lambsdorff              21            10
# 1              martin-schulz-1              35             0
# 2              michael-theurer               3             3
# 3                fabio-de-masi              21            21
# 4              sarah-ryglewski              11            11
# ..                         ...             ...           ...
# 713            verena-hartmann              11             2
# 714           martin-reichardt               1             0
# 715                marcus-buhl               1             0
# 716              anton-friesen              32            31
# 717                gyde-jensen               5             3
#
#      meta.standard_replies                                           meta.url  \
# 0                        0  https://www.abgeordnetenwatch.de/profile/alexa...
# 1                        0  https://www.abgeordnetenwatch.de/profile/marti...
# 2                        0  https://www.abgeordnetenwatch.de/profile/micha...
# 3                        0  https://www.abgeordnetenwatch.de/profile/fabio...
# 4                        0  https://www.abgeordnetenwatch.de/profile/sarah...
# ..                     ...                                                ...
# 713                      0  https://www.abgeordnetenwatch.de/profile/veren...
# 714                      0  https://www.abgeordnetenwatch.de/profile/marti...
# 715                      1  https://www.abgeordnetenwatch.de/profile/marcu...
# 716                      0  https://www.abgeordnetenwatch.de/profile/anton...
# 717                      0  https://www.abgeordnetenwatch.de/profile/gyde-...
#
#     personal.degree personal.first_name  ... personal.location.city  \
# 0               NaN           Alexander  ...                    NaN
# 1               NaN              Martin  ...               Würselen
# 2               NaN             Michael  ...         Horb am Neckar
# 3               NaN               Fabio  ...        Hamburg, Berlin
# 4               NaN               Sarah  ...                 Bremen
# ..              ...                 ...  ...                    ...
# 713             NaN              Verena  ...                    NaN
# 714             NaN              Martin  ...                    NaN
# 715             NaN              Marcus  ...               Illmenau
# 716             Dr.               Anton  ...                    NaN
# 717             NaN                Gyde  ...                    NaN
#
#     personal.location.postal_code  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 713                           NaN
# 714                           NaN
# 715                           NaN
# 716                           NaN
# 717                           NaN
#
#                                   personal.picture.url  \
# 0    https://www.abgeordnetenwatch.de/sites/abgeord...
# 1    https://www.abgeordnetenwatch.de/sites/abgeord...
# 2    https://www.abgeordnetenwatch.de/sites/abgeord...
# 3    https://www.abgeordnetenwatch.de/sites/abgeord...
# 4    https://www.abgeordnetenwatch.de/sites/abgeord...
# ..                                                 ...
# 713  https://www.abgeordnetenwatch.de/sites/abgeord...
# 714  https://www.abgeordnetenwatch.de/sites/abgeord...
# 715  https://www.abgeordnetenwatch.de/sites/abgeord...
# 716  https://www.abgeordnetenwatch.de/sites/abgeord...
# 717  https://www.abgeordnetenwatch.de/sites/abgeord...
#
#            personal.picture.copyright      party parliament.name  \
# 0    <p>Graf Alexander Lambsdorff</p>        FDP       Bundestag
# 1                                 NaN        SPD       Bundestag
# 2              <p>Michael Theurer</p>        FDP       Bundestag
# 3                    Karen Demarowitz  DIE LINKE       Bundestag
# 4                                 NaN        SPD       Bundestag
# ..                                ...        ...             ...
# 713                   Verena Hartmann        AfD       Bundestag
# 714                               NaN        AfD       Bundestag
# 715                               NaN        AfD       Bundestag
# 716                               NaN        AfD       Bundestag
# 717                               NaN        FDP       Bundestag
#
#                           parliament.uuid parliament.joined  \
# 0    60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 1    60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 2    60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 3    60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 4    60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# ..                                    ...               ...
# 713  60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 714  60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 715  60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 716  60d0787f-e311-4283-a7fd-85b9f62a9b33               NaN
# 717  60d0787f-e311-4283-a7fd-85b9f62a9b33        2017-09-24
#
#      parliament.retired     twitter_name
# 0                   NaN              NaN
# 1                   NaN     martinschulz
# 2                   NaN              NaN
# 3                   NaN      fabiodemasi
# 4                   NaN              NaN
# ..                  ...              ...
# 713                 NaN              NaN
# 714                 NaN  m_reichardt_afd
# 715                 NaN              NaN
# 716                 NaN     drfriesenmdb
# 717                 NaN            gydej
#
# [718 rows x 27 columns]

# %% [markdown]
# ### Storing the last 10 tweets of the sample MP
#
# Here we test whether we are able to store a manually specified number of tweets for selected MPs, again using the ``user_timeline``-function. Retweets are excluded using the ``include_rts`` argument. ``Tweet_mode`` is set to extended since tweets would get truncated

# %%
tweets_sample_mp = api.user_timeline(
    screen_name = twitter_string, 
    # 100 is the maximum allowed count
    count = 10,
    include_rts = False,
    # Necessary to keep full_text 
    # otherwise only the first 140 words are extracted
    tweet_mode = 'extended'
)

tweets_sample_mp

# %% [markdown]
# Using Panda's ``json_normalize``-function for transorming the dataframe into a flat table

# %%
# tweets_sample_mp.full_text.encode("utf-8")

json_data = [r._json for r in tweets_sample_mp]

tweets_df = pd.json_normalize(json_data)

# %%
#look at dataframe
tweets_df
# Out:
#                  created_at                   id               id_str  \
# 0 2021-11-26 09:00:49+00:00  1464157182186995715  1464157182186995715
# 1 2021-11-25 19:04:51+00:00  1463946804488192001  1463946804488192001
# 2 2021-11-25 13:38:48+00:00  1463864751474163718  1463864751474163718
# 3 2021-11-24 17:09:52+00:00  1463555480245223430  1463555480245223430
# 4 2021-11-24 14:50:09+00:00  1463520318358704136  1463520318358704136
# 5 2021-11-24 14:46:21+00:00  1463519363940728835  1463519363940728835
# 6 2021-11-24 10:45:44+00:00  1463458809226178561  1463458809226178561
# 7 2021-11-24 10:43:59+00:00  1463458367347777536  1463458367347777536
#
#                                            full_text  truncated  \
# 0  Herzlichen Glückwunsch @ABaerbock  @SteffiLemk...      False
# 1                       Mood https://t.co/Wt51ykKWNo      False
# 2                       ❤️💚💛 https://t.co/aPFHeKkaDD      False
# 3  Manchmal sind es die kleinen Dinge, die einen ...      False
# 4  Und auch @krusehamburg @schneidercar Sabine Po...      False
# 5  Jetzt ist er endlich da. Einfach war es nicht,...      False
# 6                 @KuehniKev Wer muss es Olaf sagen?      False
# 7                  @nnienass https://t.co/DX5ByQlGmB      False
#
#   display_text_range                                             source  \
# 0           [0, 126]  <a href="http://twitter.com/download/android" ...
# 1             [0, 4]  <a href="http://twitter.com/#!/download/ipad" ...
# 2             [0, 4]  <a href="http://twitter.com/download/android" ...
# 3           [0, 128]  <a href="http://twitter.com/#!/download/ipad" ...
# 4           [0, 120]  <a href="http://twitter.com/#!/download/ipad" ...
# 5           [0, 127]  <a href="http://twitter.com/#!/download/ipad" ...
# 6           [11, 34]  <a href="http://twitter.com/download/android" ...
# 7             [9, 9]  <a href="http://twitter.com/download/android" ...
#
#    in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  ...  \
# 0                    NaN                      None                  NaN  ...
# 1                    NaN                      None                  NaN  ...
# 2                    NaN                      None                  NaN  ...
# 3                    NaN                      None                  NaN  ...
# 4           1.463519e+18       1463519363940728835         9.374031e+08  ...
# 5                    NaN                      None                  NaN  ...
# 6           1.463457e+18       1463456677592719362         2.764750e+09  ...
# 7           1.463453e+18       1463453047271612417         1.479475e+08  ...
#
#   quoted_status.coordinates quoted_status.place quoted_status.contributors  \
# 0                       NaN                 NaN                        NaN
# 1                       NaN                 NaN                        NaN
# 2                       NaN                 NaN                        NaN
# 3                       NaN                 NaN                        NaN
# 4                       NaN                 NaN                        NaN
# 5                       NaN                 NaN                        NaN
# 6                       NaN                 NaN                        NaN
# 7                       NaN                 NaN                        NaN
#
#   quoted_status.is_quote_status quoted_status.retweet_count  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                         False                        17.0
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
#
#   quoted_status.favorite_count  quoted_status.favorited  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                        176.0                    False
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
#
#    quoted_status.retweeted  quoted_status.possibly_sensitive  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
# 2                    False                             False
# 3                      NaN                               NaN
# 4                      NaN                               NaN
# 5                      NaN                               NaN
# 6                      NaN                               NaN
# 7                      NaN                               NaN
#
#    quoted_status.lang
# 0                 NaN
# 1                 NaN
# 2                  de
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
#
# [8 rows x 151 columns]

# %%
tweets_df['created_at']
# Out:
# 0    Fri Nov 26 09:00:49 +0000 2021
# 1    Thu Nov 25 19:04:51 +0000 2021
# 2    Thu Nov 25 13:38:48 +0000 2021
# 3    Wed Nov 24 17:09:52 +0000 2021
# 4    Wed Nov 24 14:50:09 +0000 2021
# 5    Wed Nov 24 14:46:21 +0000 2021
# 6    Wed Nov 24 10:45:44 +0000 2021
# 7    Wed Nov 24 10:43:59 +0000 2021
# Name: created_at, dtype: object
